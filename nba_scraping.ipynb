# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# set up URL
url_2015 = 'https://www.basketball-reference.com/leagues/NBA_2015_per_game.html'
url_2016 = 'https://www.basketball-reference.com/leagues/NBA_2016_per_game.html'
url_2017 = 'https://www.basketball-reference.com/leagues/NBA_2017_per_game.html'
url_2018 = 'https://www.basketball-reference.com/leagues/NBA_2018_per_game.html'
url_2019 = 'https://www.basketball-reference.com/leagues/NBA_2019_per_game.html'

# %%
nba_df = pd.read_html(url_link, header=0)
print(type(nba_df))
nba_df[0]
# Out:
# <class 'list'>
#       Rk        Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0      1  Álex Abrines  SG  25  OKC  31   2  19.0  1.8   5.1  ...  .923  0.2
# 1      2    Quincy Acy  PF  28  PHO  10   0  12.3  0.4   1.8  ...  .700  0.3
# 2      3  Jaylen Adams  PG  22  ATL  34   1  12.6  1.1   3.2  ...  .778  0.3
# 3      4  Steven Adams   C  25  OKC  80  80  33.4  6.0  10.1  ...  .500  4.9
# 4      5   Bam Adebayo   C  21  MIA  82  28  23.3  3.4   5.9  ...  .735  2.0
# ..   ...           ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...  ...
# 729  528  Tyler Zeller   C  29  MEM   4   1  20.5  4.0   7.0  ...  .778  2.3
# 730  529    Ante Žižić   C  22  CLE  59  25  18.3  3.1   5.6  ...  .705  1.8
# 731  530   Ivica Zubac   C  21  TOT  59  37  17.6  3.6   6.4  ...  .802  1.9
# 732  530   Ivica Zubac   C  21  LAL  33  12  15.6  3.4   5.8  ...  .864  1.6
# 733  530   Ivica Zubac   C  21  LAC  26  25  20.2  3.8   7.2  ...  .733  2.3
#
# ...

# %%
# put the list into a dataframe
df_2019 = nba_df[0]
# Out:
#       Rk         Player  Pos  Age   Tm  G  GS    MP   FG  FGA  ...  FT%  ORB  \
# 498   Rk         Player  Pos  Age   Tm  G  GS    MP   FG  FGA  ...  FT%  ORB
# 694   Rk         Player  Pos  Age   Tm  G  GS    MP   FG  FGA  ...  FT%  ORB
# 22    Rk         Player  Pos  Age   Tm  G  GS    MP   FG  FGA  ...  FT%  ORB
# 186   Rk         Player  Pos  Age   Tm  G  GS    MP   FG  FGA  ...  FT%  ORB
# 411   Rk         Player  Pos  Age   Tm  G  GS    MP   FG  FGA  ...  FT%  ORB
# ..   ...            ...  ...  ...  ... ..  ..   ...  ...  ...  ...  ...  ...
# 702  508    Okaro White   PF   26  WAS  3   0   2.0  0.0  0.7  ...  NaN  0.3
# 34    28      Ron Baker   SG   25  WAS  4   0  11.3  0.0  1.0  ...  NaN  0.0
# 495  359  Eric Moreland   PF   27  PHO  1   0   5.0  0.0  0.0  ...  NaN  0.0
# 640  460   Ray Spalding   PF   21  DAL  1   0   1.0  0.0  0.0  ...  NaN  0.0
# 18    17   Ike Anigbogu    C   20  IND  3   0   2.0  0.0  1.0  ...  NaN  0.3
#
#      DRB  TRB  AST  STL  BLK  TOV   PF  PTS
# ...

# %%
# drop excess header rows
clean_df = df_2019.drop(df_2019[df_2019.Age == 'Age'].index)
len(clean_df)
# Out:
# 708

# %%
import seaborn as sns

# %%
pts = clean_df.PTS.astype(float)
sns.displot(pts, binwidth=3, bins=[5, 10, 15, 20, 25, 30, 35, 40])

# %%
max_ = clean_df.PTS.max()
max_
# Out:
# '9.9'

# %%
clean_df.dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object
